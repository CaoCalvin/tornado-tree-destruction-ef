# %%
import os
import cv2
import sys

def rescale_image(image_path: str, scale: float) -> None:
    image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
    if image is None:
        print(f"Failed to read image: {image_path}")
        return

    height, width = image.shape[:2]
    new_size = (int(width * scale), int(height * scale))

    resized = cv2.resize(image, new_size, interpolation=cv2.INTER_AREA)

    # Overwrite original image
    success = cv2.imwrite(image_path, resized)
    if not success:
        print(f"Failed to write resized image: {image_path}")

def rescale_all_tifs(folder_path: str, scale: float) -> None:
    if not os.path.isdir(folder_path):
        raise ValueError(f"Provided path is not a directory: {folder_path}")
    if scale <= 0:
        raise ValueError("Scaling factor must be positive.")

    for root, _, files in os.walk(folder_path):
        for filename in files:
            if filename.lower().endswith(('.tif', '.tiff')):
                full_path = os.path.join(root, filename)
                print(f"Rescaling: {full_path}")
                rescale_image(full_path, scale)

if __name__ == "__main__":
    folder = r"C:\Users\kevin\dev\tornado-tree-destruction-ef\dataset\images\ayr"
    try:
        scale_factor = 0.5
    except ValueError:
        print("Scaling factor must be a number.")
        sys.exit(1)

    rescale_all_tifs(folder, scale_factor)
# Out:
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\centreglassville\Glassville_ortho_5cm16.TIF
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\crozier\22_Crozier_461000_5385000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\dugwal\22_Dugwal_499000_5383000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\dugwal\22_Dugwal_499000_5384000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\dugwal\22_Dugwal_500000_5381000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\dugwal\22_Dugwal_500000_5382000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\dugwal\22_Dugwal_500000_5383000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\dugwal\22_Dugwal_501000_5381000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\dugwal\22_Dugwal_501000_5382000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\dugwal\22_Dugwal_502000_5380000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\dugwal\22_Dugwal_503000_5379000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\dugwal\22_Dugwal_503000_5380000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\gooseberry\22_Gooseberry_598000_5419000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\gooseberry\22_Gooseberry_598000_5420000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\gooseberry\22_Gooseberry_599000_5419000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\gooseberry\22_Gooseberry_599000_5420000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\gowanmarsh\22_Gowanmarsh_484000_5390000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\gowanmarsh\22_Gowanmarsh_485000_5389000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\gowanmarsh\22_Gowanmarsh_485000_5390000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\kaoskauta\22_Kaoskauta_493000_5468000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\kaoskauta\22_Kaoskauta_495000_5468000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\lacombon\22_Lac_Ombon_282000_5219000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\lacombon\22_Lac_Ombon_283000_5221000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\lacpedro\22_Lac_Pedro_309000_5239000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\lacpedro\22_Lac_Pedro_310000_5238000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\lacpedro\22_Lac_Pedro_310000_5239000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\lacpedro\22_Lac_Pedro_311000_5239000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\lacpedro\22_Lac_Pedro_312000_5242000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\lacpedro\22_Lac_Pedro_313000_5242000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\lacpedro\22_Lac_Pedro_313000_5243000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\murray\2019_Lac Murray_597700_5262700.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\murray\2019_Lac Murray_598700_5262200.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\murray\2019_Lac Murray_599200_5262200.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\murray\2019_Lac Murray_599700_5261200.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\murray\2019_Lac Murray_599700_5262200.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\murray\2019_Lac Murray_606200_5264200.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\woodstock\22_Woodstock_336000_5683000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\woodstock\22_Woodstock_338000_5681000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\woodstock\22_Woodstock_339000_5682000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\woodstock\22_Woodstock_344000_5679000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\woodstock\22_Woodstock_346000_5681000.tif
# Rescaling: C:\Users\kevin\Documents\downloaded_tifs\woodstock\22_Woodstock_356000_5679000.tif
